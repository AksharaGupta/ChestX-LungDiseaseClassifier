# %%
import os
import numpy as np
from keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array
from keras.models import Sequential, load_model
import time

start = time.time()

#Define Path
model_path = './models/model.json'
model_weights_path = './models/weights.h5'
test_path = 'data/alien_test'
diseases = ['Cardiomegaly','Emphysema','Effusion','Hernia','Nodule','Pneumothorax','Atelectasis','Pleural_Thickening','Mass','Edema','Consolidation','Infiltration','Fibrosis','Pneumonia','No Finding']
#diseases = diseases.sort()
diseases.sort()

#Load the pre-trained models
model = load_model(model_path)
model.load_weights(model_weights_path)

#Define image parameters
img_width, img_height = 150, 150

#Prediction Function
def predict(file):
  x = load_img(file, target_size=(img_width,img_height))
  x = img_to_array(x)
  x = np.expand_dims(x, axis=0)
  array = model.predict(x)
  result = array[0]
  #print(result)
  answer = np.argmax(result)
  L = []
  for i in range(len(result)):
    if result[i] > 0:
        L.append ({diseases[i]:result[i]})
  print (L)
  #print (answer)
  '''if answer == 1:
    print("Predicted: chair")
  elif answer == 0:
    print("Predicted: Motorbikes")
  elif answer == 2:
    print("Predicted: soccer_ball")'''

  return answer

#Walk the directory for every image
for i, ret in enumerate(os.walk(test_path)):
  for i, filename in enumerate(ret[2]):
    if filename.startswith("."):
      continue
    
    print(ret[0] + '/' + filename)
    result = predict(ret[0] + '/' + filename)
    print('Model output: ',diseases[result])

#Calculate execution time
end = time.time()
dur = end-start

if dur<60:
    print("Execution Time:",dur,"seconds")
elif dur>60 and dur<3600:
    dur=dur/60
    print("Execution Time:",dur,"minutes")
else:
    dur=dur/(60*60)
    print("Execution Time:",dur,"hours")
# Out:
# data/alien_test/00000061_002.png
# [[4.0114486e-07 0.0000000e+00 0.0000000e+00 0.0000000e+00 1.2245510e-32
#   0.0000000e+00 0.0000000e+00 0.0000000e+00 5.6172713e-28 0.0000000e+00
#   9.9999964e-01 2.1133361e-30 0.0000000e+00 0.0000000e+00 0.0000000e+00]]
# [{'Atelectasis': 4.0114486e-07}, {'Effusion': 1.224551e-32}, {'Infiltration': 5.6172713e-28}, {'No Finding': 0.99999964}, {'Nodule': 2.113336e-30}]
# Model output:  No Finding
# data/alien_test/00000861_002.png
# [[1.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00 2.4974754e-13
#   0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00
#   9.2813454e-26 0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00]]
# [{'Atelectasis': 1.0}, {'Effusion': 2.4974754e-13}, {'No Finding': 9.2813454e-26}]
# Model output:  Atelectasis
# data/alien_test/00009863_007.png
# [[3.943286e-20 0.000000e+00 0.000000e+00 0.000000e+00 0.000000e+00
#   0.000000e+00 0.000000e+00 0.000000e+00 0.000000e+00 0.000000e+00
#   1.000000e+00 0.000000e+00 0.000000e+00 0.000000e+00 0.000000e+00]]
# [{'Atelectasis': 3.943286e-20}, {'No Finding': 1.0}]
# Model output:  No Finding
# data/alien_test/00018124_000.png
# [[6.0683878e-30 0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00
#   0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00
#   1.0000000e+00 1.1206651e-37 0.0000000e+00 0.0000000e+00 0.0000000e+00]]
# [{'Atelectasis': 6.068388e-30}, {'No Finding': 1.0}, {'Nodule': 1.1206651e-37}]
# Model output:  No Finding
# Execution Time: 3.176158905029297 seconds
