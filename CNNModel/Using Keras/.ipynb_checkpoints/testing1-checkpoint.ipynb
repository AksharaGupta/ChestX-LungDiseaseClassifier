# %%
import os
import numpy as np
from keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array
from keras.models import Sequential, load_model, model_from_json
import time
import pandas as pd

start = time.time()

#Define Path
sample_set = pd.read_csv("../Dataentry.csv")
model_weights_path = './models/weights.h5'
model_path = './models/CNN.best.from_scratch.hdf5'
test_path = 'data/alien_test'
diseases = ['Cardiomegaly','Emphysema','Effusion','Hernia','Nodule','Pneumothorax','Atelectasis','Pleural_Thickening','Mass','Edema','Consolidation','Infiltration','Fibrosis','Pneumonia','No Finding']
#diseases = diseases.sort()
diseases.sort()
labels = sample_set[['Image Index','Finding Labels']]

#Load the pre-trained models
#json_file = open('./models/model1.json','r')
# loaded_model_json = json_file.read()
# json_file.close()
# loaded_model = model_from_json(loaded_model_json)
loaded_model=load_model(model_path)
loaded_model.load_weights(model_weights_path)


#Prediction Function
def predict(file):
  x = load_img(file, target_size=(150,150))
  x = img_to_array(x)
  x = np.expand_dims(x, axis=0)
  array = loaded_model.predict(x)
  #print (array)
  result = array[0]
  #print(result)
  answer = np.argmax(result)
  diss=[]
  vals=[]
  for i in range(len(result)):
    if result[i] > 0:
        diss.append(diseases[i])
        vals.append(result[i])
  
  final_op=sorted(zip(diss,vals), reverse=True)[:5]
  print ("Model Output: ",final_op)
  return answer,diss

correct=0
wrong=0
total=0
#Walk the directory for every image
for i, ret in enumerate(os.walk(test_path)):
  for i, filename in enumerate(ret[2]):
    if filename.startswith("."):
      continue
    
    print(ret[0] + '/' + filename)
    total=total+1
    #get predicted result from model
    result,modellist = predict(ret[0] + '/' + filename)
    print('Most Probable Predicted disease: ',diseases[result])
    
    #find actual value from dataset
    actual_output=labels[labels['Image Index']==filename]['Finding Labels']
    string_output=str(actual_output)
    spaced=string_output[string_output.find(" ")+1:string_output.find("\n")]
    actuallist=spaced.split("|")
    actuallist[0]=actuallist[0].lstrip()
    
    checking=0
    for i in modellist:
        if(i in actuallist):
            checking=1
            break
            
    if(checking==1):
        correct=correct+1
    elif(checking==0):
        wrong=wrong+1
    
    print('Actual output:',spaced)
    print ("-------------")
    
#print test results
print("\n\n\nNumber of correctly detected images: ",correct,"/",total)
print("Number of wrongly detected images: ",wrong,"/",total)
#Calculate execution time
end = time.time()
dur = end-start

if dur<60:
    print("Execution Time:",dur,"seconds")
elif dur>60 and dur<3600:
    dur=dur/60
    print("Execution Time:",dur,"minutes")
else:
    dur=dur/(60*60)
    print("Execution Time:",dur,"hours")
# Out:
# data/alien_test/00000013_005.png
# Model Output:  [{'Edema': 7.5084484e-16}, {'Infiltration': 1.0}]
# [(1.0, 'Infiltration'), (7.5084484e-16, 'Edema')]
# Most Probable Predicted disease:  Infiltration
# Actual output:    Emphysema|Infiltration|Pleural_Thickening|Pneu...
# -------------
# data/alien_test/00000040_003.png
# Model Output:  [{'Infiltration': 1.0}, {'Mass': 9.96976e-38}]
# [(1.0, 'Infiltration'), (9.96976e-38, 'Mass')]
# Most Probable Predicted disease:  Infiltration
# Actual output:    Consolidation|Mass
# -------------
# data/alien_test/00000061_025.png
# Model Output:  [{'Atelectasis': 6.896952e-38}, {'Cardiomegaly': 1.7735818e-24}, {'Hernia': 2.0112075e-28}, {'Infiltration': 2.7328323e-19}, {'Mass': 1.0}, {'No Finding': 2.2440351e-18}]
# [(1.0, 'Mass'), (2.2440351e-18, 'No Finding'), (2.7328323e-19, 'Infiltration'), (1.7735818e-24, 'Cardiomegaly'), (2.0112075e-28, 'Hernia')]
# Most Probable Predicted disease:  Mass
# Actual output:    Consolidation|Effusion|Infiltration|Nodule
# -------------
# data/alien_test/00000103_001.png
# Model Output:  [{'Infiltration': 1.0}]
# [(1.0, 'Infiltration')]
# Most Probable Predicted disease:  Infiltration
# Actual output:    Mass|Pneumothorax
# -------------
# data/alien_test/00000118_011.png
# Model Output:  [{'Hernia': 5.510807e-37}, {'Infiltration': 1.0}, {'Mass': 1.6971761e-36}]
# [(1.0, 'Infiltration'), (1.6971761e-36, 'Mass'), (5.510807e-37, 'Hernia')]
# Most Probable Predicted disease:  Infiltration
# Actual output:    Pneumothorax
# -------------
# data/alien_test/00000246_016.png
# Model Output:  [{'Atelectasis': 8.701836e-34}, {'Cardiomegaly': 9.071715e-09}, {'Consolidation': 5.759781e-24}, {'Edema': 3.468996e-24}, {'Emphysema': 2.186077e-22}, {'Fibrosis': 1.3624343e-37}, {'Infiltration': 8.508968e-23}, {'Mass': 1.0}, {'No Finding': 1.0219835e-12}]
# [(1.0, 'Mass'), (9.071715e-09, 'Cardiomegaly'), (1.0219835e-12, 'No Finding'), (2.186077e-22, 'Emphysema'), (8.508968e-23, 'Infiltration')]
# Most Probable Predicted disease:  Mass
# Actual output:    Consolidation|Mass
# -------------
# data/alien_test/00000372_002.png
# Model Output:  [{'Edema': 1.3628331e-24}, {'Infiltration': 1.0}]
# [(1.0, 'Infiltration'), (1.3628331e-24, 'Edema')]
# Most Probable Predicted disease:  Infiltration
# Actual output:    Pneumothorax
# -------------
# data/alien_test/00000376_007.png
# Model Output:  [{'Infiltration': 1.0}, {'Mass': 2.2060578e-21}]
# [(1.0, 'Infiltration'), (2.2060578e-21, 'Mass')]
# Most Probable Predicted disease:  Infiltration
# Actual output:    Emphysema|Mass
# -------------
# data/alien_test/00000467_013.png
# Model Output:  [{'Consolidation': 0.00019626833}, {'Edema': 0.9998037}, {'Effusion': 2.3975397e-34}, {'Emphysema': 4.293134e-32}]
# [(0.9998037, 'Edema'), (0.00019626833, 'Consolidation'), (4.293134e-32, 'Emphysema'), (2.3975397e-34, 'Effusion')]
# Most Probable Predicted disease:  Edema
# Actual output:    Pneumothorax
# -------------
# data/alien_test/00000468_005.png
# Model Output:  [{'Atelectasis': 9.134491e-18}, {'Cardiomegaly': 2.409112e-28}, {'Effusion': 1.1482914e-15}, {'Emphysema': 7.487406e-21}, {'Hernia': 4.0800006e-23}, {'Mass': 1.0}, {'No Finding': 3.673386e-36}, {'Nodule': 3.72476e-30}]
# [(1.0, 'Mass'), (1.1482914e-15, 'Effusion'), (9.134491e-18, 'Atelectasis'), (7.487406e-21, 'Emphysema'), (4.0800006e-23, 'Hernia')]
# Most Probable Predicted disease:  Mass
# Actual output:    Emphysema|Pneumothorax
# -------------
# data/alien_test/00000580_001.png
# Model Output:  [{'Edema': 1.4453117e-21}, {'Emphysema': 1.0594253e-25}, {'Hernia': 1.9467382e-33}, {'Infiltration': 1.0}, {'Mass': 9.029816e-28}]
# [(1.0, 'Infiltration'), (1.4453117e-21, 'Edema'), (1.0594253e-25, 'Emphysema'), (9.029816e-28, 'Mass'), (1.9467382e-33, 'Hernia')]
# Most Probable Predicted disease:  Infiltration
# Actual output:    Mass|Pleural_Thickening
# -------------
# data/alien_test/00001385_004.png
# Model Output:  [{'Infiltration': 1.0}, {'Mass': 5.836186e-35}]
# [(1.0, 'Infiltration'), (5.836186e-35, 'Mass')]
# Most Probable Predicted disease:  Infiltration
# Actual output:    Cardiomegaly
# -------------
# data/alien_test/00001429_007.png
# Model Output:  [{'Atelectasis': 1.4236217e-35}, {'Emphysema': 1.9404934e-35}, {'Hernia': 4.4809927e-13}, {'Infiltration': 1.0}, {'Mass': 1.692219e-12}, {'Nodule': 1.8970711e-32}]
# [(1.0, 'Infiltration'), (1.692219e-12, 'Mass'), (4.4809927e-13, 'Hernia'), (1.8970711e-32, 'Nodule'), (1.9404934e-35, 'Emphysema')]
# Most Probable Predicted disease:  Infiltration
# Actual output:    Mass|Pneumothorax
# -------------
# data/alien_test/00001483_020.png
# Model Output:  [{'Edema': 3.2384295e-12}, {'Emphysema': 6.091581e-30}, {'Infiltration': 1.0}]
# [(1.0, 'Infiltration'), (3.2384295e-12, 'Edema'), (6.091581e-30, 'Emphysema')]
# Most Probable Predicted disease:  Infiltration
# Actual output:    Mass
# -------------
# data/alien_test/00001483_023.png
# Model Output:  [{'Cardiomegaly': 1.5818729e-32}, {'Consolidation': 1.0}, {'Edema': 1.5538763e-10}, {'No Finding': 1.3906407e-24}]
# [(1.0, 'Consolidation'), (1.5538763e-10, 'Edema'), (1.3906407e-24, 'No Finding'), (1.5818729e-32, 'Cardiomegaly')]
# Most Probable Predicted disease:  Consolidation
# Actual output:    Atelectasis|Effusion|Infiltration|Mass
# -------------
# data/alien_test/00001517_005.png
# Model Output:  [{'Edema': 5.652327e-22}, {'Infiltration': 1.0}]
# [(1.0, 'Infiltration'), (5.652327e-22, 'Edema')]
# Most Probable Predicted disease:  Infiltration
# Actual output:    Atelectasis|Mass
# -------------
# data/alien_test/00001609_002.png
# Model Output:  [{'Consolidation': 5.0898963e-37}, {'Edema': 1.0794647e-06}, {'Emphysema': 1.330192e-37}, {'Infiltration': 0.9999989}]
# [(0.9999989, 'Infiltration'), (1.0794647e-06, 'Edema'), (5.0898963e-37, 'Consolidation'), (1.330192e-37, 'Emphysema')]
# Most Probable Predicted disease:  Infiltration
# Actual output:    Effusion|Pneumothorax
# -------------
# data/alien_test/00001684_025.png
# Model Output:  [{'Edema': 6.55376e-38}, {'Emphysema': 2.1490494e-31}, {'Infiltration': 1.0}, {'Mass': 5.4833088e-17}, {'No Finding': 4.709094e-38}]
# [(1.0, 'Infiltration'), (5.4833088e-17, 'Mass'), (2.1490494e-31, 'Emphysema'), (6.55376e-38, 'Edema'), (4.709094e-38, 'No Finding')]
# Most Probable Predicted disease:  Infiltration
# Actual output:    Atelectasis|Effusion
# -------------
# data/alien_test/00001736_013.png
# Model Output:  [{'Atelectasis': 4.3237587e-37}, {'Cardiomegaly': 1.155826e-12}, {'Consolidation': 1.0656844e-20}, {'Edema': 7.918308e-08}, {'Emphysema': 2.6158067e-12}, {'Fibrosis': 1.0168279e-22}, {'Hernia': 1.6158253e-29}, {'Infiltration': 0.002538866}, {'Mass': 0.99746096}, {'No Finding': 6.1934215e-24}]
# [(0.99746096, 'Mass'), (0.002538866, 'Infiltration'), (7.918308e-08, 'Edema'), (2.6158067e-12, 'Emphysema'), (1.155826e-12, 'Cardiomegaly')]
# Most Probable Predicted disease:  Mass
# Actual output:    Atelectasis|Infiltration
# -------------
# data/alien_test/00001782_000.png
# Model Output:  [{'Cardiomegaly': 8.644156e-22}, {'Consolidation': 1.1445088e-37}, {'Edema': 3.7678804e-20}, {'Emphysema': 7.76186e-13}, {'Fibrosis': 3.7719195e-36}, {'Infiltration': 0.99839526}, {'Mass': 0.0016047492}, {'No Finding': 2.1147997e-27}]
# [(0.99839526, 'Infiltration'), (0.0016047492, 'Mass'), (7.76186e-13, 'Emphysema'), (3.7678804e-20, 'Edema'), (8.644156e-22, 'Cardiomegaly')]
# Most Probable Predicted disease:  Infiltration
# Actual output:    Atelectasis|Effusion|Infiltration|Nodule
# -------------
# data/alien_test/00001797_002.png
# Model Output:  [{'Cardiomegaly': 1.7788217e-38}, {'Edema': 9.880564e-16}, {'Emphysema': 0.9906871}, {'Infiltration': 0.009312956}, {'Mass': 2.4380495e-22}, {'No Finding': 1.2510514e-38}]
# [(0.9906871, 'Emphysema'), (0.009312956, 'Infiltration'), (9.880564e-16, 'Edema'), (2.4380495e-22, 'Mass'), (1.7788217e-38, 'Cardiomegaly')]
# Most Probable Predicted disease:  Emphysema
# Actual output:    Atelectasis
# -------------
# data/alien_test/00001836_048.png
# Model Output:  [{'Consolidation': 3.217422e-06}, {'Edema': 0.9999968}]
# [(0.9999968, 'Edema'), (3.217422e-06, 'Consolidation')]
# Most Probable Predicted disease:  Edema
# Actual output:    Effusion|Infiltration|Nodule
# -------------
# data/alien_test/00001836_076.png
# Model Output:  [{'Atelectasis': 1.0866673e-24}, {'Cardiomegaly': 0.0015307042}, {'Consolidation': 4.9150543e-21}, {'Edema': 9.915307e-24}, {'Effusion': 1.1178379e-19}, {'Emphysema': 3.6385998e-19}, {'Fibrosis': 4.0620436e-36}, {'Hernia': 1.19063e-29}, {'Infiltration': 2.2710421e-28}, {'Mass': 0.9984693}, {'No Finding': 1.2543921e-09}]
# [(0.9984693, 'Mass'), (0.0015307042, 'Cardiomegaly'), (1.2543921e-09, 'No Finding'), (3.6385998e-19, 'Emphysema'), (1.1178379e-19, 'Effusion')]
# Most Probable Predicted disease:  Mass
# Actual output:    Mass|Nodule
# -------------
# data/alien_test/00001900_038.png
# Model Output:  [{'Hernia': 5.913281e-26}, {'Mass': 1.0}, {'No Finding': 1.28566704e-23}]
# [(1.0, 'Mass'), (1.28566704e-23, 'No Finding'), (5.913281e-26, 'Hernia')]
# Most Probable Predicted disease:  Mass
# Actual output:    Effusion|Mass|Pleural_Thickening
# -------------
# data/alien_test/00001968_000.png
# Model Output:  [{'Atelectasis': 2.4542516e-19}, {'Cardiomegaly': 3.652259e-30}, {'Edema': 1.4191552e-34}, {'Effusion': 1.1064736e-22}, {'Emphysema': 0.00020381571}, {'Fibrosis': 3.7119055e-33}, {'Hernia': 4.7251253e-17}, {'Infiltration': 5.5041005e-06}, {'Mass': 0.9997907}, {'Nodule': 1.175197e-13}]
# [(0.9997907, 'Mass'), (0.00020381571, 'Emphysema'), (5.5041005e-06, 'Infiltration'), (1.175197e-13, 'Nodule'), (4.7251253e-17, 'Hernia')]
# Most Probable Predicted disease:  Mass
# Actual output:    Pneumothorax
# -------------
# data/alien_test/00001982_000.png
# Model Output:  [{'Atelectasis': 1.3258981e-24}, {'Emphysema': 3.0235655e-20}, {'Hernia': 4.0109385e-06}, {'Infiltration': 0.9996469}, {'Mass': 0.00034904346}, {'Nodule': 6.658779e-31}]
# [(0.9996469, 'Infiltration'), (0.00034904346, 'Mass'), (4.0109385e-06, 'Hernia'), (3.0235655e-20, 'Emphysema'), (1.3258981e-24, 'Atelectasis')]
# Most Probable Predicted disease:  Infiltration
# Actual output:    Atelectasis
# -------------
# data/alien_test/00002032_004.png
# Model Output:  [{'Atelectasis': 1.9864917e-14}, {'Cardiomegaly': 2.2236423e-05}, {'Consolidation': 7.177586e-15}, {'Edema': 3.156483e-19}, {'Effusion': 3.2164316e-19}, {'Emphysema': 9.664764e-15}, {'Fibrosis': 5.5253624e-27}, {'Hernia': 2.397327e-33}, {'Infiltration': 1.7798958e-21}, {'Mass': 0.9999777}, {'No Finding': 6.9102837e-15}, {'Nodule': 1.1432122e-32}]
# [(0.9999777, 'Mass'), (2.2236423e-05, 'Cardiomegaly'), (1.9864917e-14, 'Atelectasis'), (9.664764e-15, 'Emphysema'), (7.177586e-15, 'Consolidation')]
# Most Probable Predicted disease:  Mass
# Actual output:    Atelectasis
# -------------
# data/alien_test/00002058_004.png
# Model Output:  [{'Edema': 5.502872e-35}, {'Emphysema': 5.847957e-26}, {'Infiltration': 1.0}, {'Mass': 1.3866176e-20}]
# [(1.0, 'Infiltration'), (1.3866176e-20, 'Mass'), (5.847957e-26, 'Emphysema'), (5.502872e-35, 'Edema')]
# Most Probable Predicted disease:  Infiltration
# Actual output:    Atelectasis|Emphysema
# -------------
# data/alien_test/00002066_014.png
# Model Output:  [{'Atelectasis': 1.9193204e-35}, {'Effusion': 5.28121e-35}, {'Hernia': 4.0461584e-19}, {'Mass': 1.0}]
# [(1.0, 'Mass'), (4.0461584e-19, 'Hernia'), (5.28121e-35, 'Effusion'), (1.9193204e-35, 'Atelectasis')]
# Most Probable Predicted disease:  Mass
# Actual output:    Nodule
# -------------
# data/alien_test/00002106_001.png
# Model Output:  [{'Atelectasis': 1.5935395e-19}, {'Cardiomegaly': 9.648176e-20}, {'Edema': 4.805785e-34}, {'Effusion': 5.466277e-10}, {'Emphysema': 0.00643548}, {'Fibrosis': 2.514508e-34}, {'Hernia': 3.397165e-10}, {'Infiltration': 1.2909535e-22}, {'Mass': 0.99356455}, {'No Finding': 1.2099527e-21}, {'Nodule': 1.7886804e-19}]
# [(0.99356455, 'Mass'), (0.00643548, 'Emphysema'), (5.466277e-10, 'Effusion'), (3.397165e-10, 'Hernia'), (1.7886804e-19, 'Nodule')]
# Most Probable Predicted disease:  Mass
# Actual output:    Pneumothorax
# -------------
# data/alien_test/00002208_009.png
# Model Output:  [{'Edema': 1.7646313e-11}, {'Emphysema': 4.3714905e-25}, {'Infiltration': 1.0}, {'Mass': 5.108981e-31}]
# [(1.0, 'Infiltration'), (1.7646313e-11, 'Edema'), (4.3714905e-25, 'Emphysema'), (5.108981e-31, 'Mass')]
# Most Probable Predicted disease:  Infiltration
# Actual output:    Atelectasis|Infiltration
# -------------
# data/alien_test/00002278_000.png
# Model Output:  [{'Hernia': 2.9188139e-09}, {'Infiltration': 0.8460607}, {'Mass': 0.15393928}]
# [(0.8460607, 'Infiltration'), (0.15393928, 'Mass'), (2.9188139e-09, 'Hernia')]
# Most Probable Predicted disease:  Infiltration
# Actual output:    Cardiomegaly|Effusion
# -------------
# data/alien_test/00002371_007.png
# Model Output:  [{'Emphysema': 4.427309e-32}, {'Infiltration': 1.0}, {'Mass': 1.7122395e-18}]
# [(1.0, 'Infiltration'), (1.7122395e-18, 'Mass'), (4.427309e-32, 'Emphysema')]
# Most Probable Predicted disease:  Infiltration
# Actual output:    Atelectasis|Nodule
# -------------
# data/alien_test/00002466_006.png
# Model Output:  [{'Infiltration': 1.0}, {'Mass': 5.6169446e-38}]
# [(1.0, 'Infiltration'), (5.6169446e-38, 'Mass')]
# Most Probable Predicted disease:  Infiltration
# Actual output:    Mass
# -------------
# data/alien_test/00002491_004.png
# Model Output:  [{'Atelectasis': 9.038708e-28}, {'Cardiomegaly': 1.2816152e-34}, {'Emphysema': 7.73029e-31}, {'Hernia': 2.0650204e-14}, {'Infiltration': 2.324317e-14}, {'Mass': 1.0}, {'No Finding': 2.3140474e-35}]
# [(1.0, 'Mass'), (2.324317e-14, 'Infiltration'), (2.0650204e-14, 'Hernia'), (9.038708e-28, 'Atelectasis'), (7.73029e-31, 'Emphysema')]
# Most Probable Predicted disease:  Mass
# Actual output:    Atelectasis
# -------------
# data/alien_test/00002570_004.png
# Model Output:  [{'Edema': 2.0096656e-21}, {'Infiltration': 1.0}]
# [(1.0, 'Infiltration'), (2.0096656e-21, 'Edema')]
# Most Probable Predicted disease:  Infiltration
# Actual output:    Atelectasis
# -------------
# data/alien_test/00002720_004.png
# Model Output:  [{'Atelectasis': 9.909729e-32}, {'Cardiomegaly': 1.8728389e-25}, {'Edema': 1.2671079e-36}, {'Emphysema': 1.3367836e-18}, {'Hernia': 2.8213188e-38}, {'Infiltration': 6.261447e-23}, {'Mass': 1.0}, {'No Finding': 1.8357906e-30}, {'Nodule': 2.1207186e-37}]
# [(1.0, 'Mass'), (1.3367836e-18, 'Emphysema'), (6.261447e-23, 'Infiltration'), (1.8728389e-25, 'Cardiomegaly'), (1.8357906e-30, 'No Finding')]
# Most Probable Predicted disease:  Mass
# Actual output:    Atelectasis|Consolidation|Effusion|Emphysema
# -------------
# data/alien_test/00002856_014.png
# Model Output:  [{'Edema': 1.1477537e-36}, {'Infiltration': 1.0}]
# [(1.0, 'Infiltration'), (1.1477537e-36, 'Edema')]
# Most Probable Predicted disease:  Infiltration
# Actual output:    Atelectasis|Infiltration
# -------------
# data/alien_test/00002856_026.png
# Model Output:  [{'Atelectasis': 5.1394917e-32}, {'Cardiomegaly': 1.1106469e-37}, {'Effusion': 5.8208576e-38}, {'Hernia': 3.9360482e-32}, {'Mass': 1.0}]
# [(1.0, 'Mass'), (5.1394917e-32, 'Atelectasis'), (3.9360482e-32, 'Hernia'), (1.1106469e-37, 'Cardiomegaly'), (5.8208576e-38, 'Effusion')]
# Most Probable Predicted disease:  Mass
# Actual output:    Atelectasis|Effusion
# -------------
# data/alien_test/00002927_002.png
# Model Output:  [{'Edema': 1.5398098e-24}, {'Emphysema': 1.1311359e-30}, {'Infiltration': 1.0}, {'Mass': 5.8802936e-37}]
# [(1.0, 'Infiltration'), (1.5398098e-24, 'Edema'), (1.1311359e-30, 'Emphysema'), (5.8802936e-37, 'Mass')]
# Most Probable Predicted disease:  Infiltration
# Actual output:    Atelectasis
# -------------
# data/alien_test/00003129_011.png
# Model Output:  [{'Edema': 6.281978e-37}, {'Emphysema': 8.0442853e-28}, {'Infiltration': 1.0}, {'Mass': 1.772277e-16}]
# [(1.0, 'Infiltration'), (1.772277e-16, 'Mass'), (8.0442853e-28, 'Emphysema'), (6.281978e-37, 'Edema')]
# Most Probable Predicted disease:  Infiltration
# Actual output:    Cardiomegaly|Infiltration
# -------------
# data/alien_test/00003198_009.png
# Model Output:  [{'Cardiomegaly': 2.5314957e-37}, {'Emphysema': 1.7939787e-27}, {'Hernia': 7.9642273e-35}, {'Infiltration': 8.225903e-08}, {'Mass': 0.9999999}, {'No Finding': 2.4039953e-38}]
# [(0.9999999, 'Mass'), (8.225903e-08, 'Infiltration'), (1.7939787e-27, 'Emphysema'), (7.9642273e-35, 'Hernia'), (2.5314957e-37, 'Cardiomegaly')]
# Most Probable Predicted disease:  Mass
# Actual output:    Atelectasis|Effusion
# -------------
# data/alien_test/00003292_007.png
# Model Output:  [{'Edema': 9.692278e-12}, {'Emphysema': 1.6234096e-28}, {'Infiltration': 1.0}]
# [(1.0, 'Infiltration'), (9.692278e-12, 'Edema'), (1.6234096e-28, 'Emphysema')]
# Most Probable Predicted disease:  Infiltration
# Actual output:    Atelectasis|Consolidation
# -------------
# data/alien_test/00003292_009.png
# Model Output:  [{'Edema': 0.98597497}, {'Emphysema': 0.014024425}, {'Infiltration': 6.5766636e-07}, {'Mass': 8.149272e-30}, {'No Finding': 5.7431623e-38}]
# [(0.98597497, 'Edema'), (0.014024425, 'Emphysema'), (6.5766636e-07, 'Infiltration'), (8.149272e-30, 'Mass'), (5.7431623e-38, 'No Finding')]
# Most Probable Predicted disease:  Edema
# Actual output:    Atelectasis|Consolidation
# -------------
# data/alien_test/00004188_011.png
# Model Output:  [{'Infiltration': 1.0}]
# [(1.0, 'Infiltration')]
# Most Probable Predicted disease:  Infiltration
# Actual output:    Consolidation|Pleural_Thickening
# -------------
# data/alien_test/00004507_000.png
# Model Output:  [{'Infiltration': 1.0}, {'Mass': 6.1370975e-19}, {'No Finding': 1.7337274e-38}]
# [(1.0, 'Infiltration'), (6.1370975e-19, 'Mass'), (1.7337274e-38, 'No Finding')]
# Most Probable Predicted disease:  Infiltration
# Actual output:    Pleural_Thickening
# -------------
# data/alien_test/00004750_000.png
# Model Output:  [{'Emphysema': 7.289748e-38}, {'Infiltration': 1.0}, {'Mass': 2.5668817e-15}]
# [(1.0, 'Infiltration'), (2.5668817e-15, 'Mass'), (7.289748e-38, 'Emphysema')]
# Most Probable Predicted disease:  Infiltration
# Actual output:    Pleural_Thickening
# -------------
# data/alien_test/00004750_004.png
# Model Output:  [{'Cardiomegaly': 5.322567e-29}, {'Edema': 3.8948256e-24}, {'Emphysema': 2.676343e-30}, {'Infiltration': 1.0}, {'Mass': 3.910159e-09}, {'No Finding': 4.0154898e-23}]
# [(1.0, 'Infiltration'), (3.910159e-09, 'Mass'), (4.0154898e-23, 'No Finding'), (3.8948256e-24, 'Edema'), (5.322567e-29, 'Cardiomegaly')]
# Most Probable Predicted disease:  Infiltration
# Actual output:    Effusion|Pleural_Thickening
# -------------
# data/alien_test/00004832_003.png
# Model Output:  [{'Emphysema': 4.262312e-34}, {'Infiltration': 1.0}, {'Mass': 1.6823634e-21}]
# [(1.0, 'Infiltration'), (1.6823634e-21, 'Mass'), (4.262312e-34, 'Emphysema')]
# Most Probable Predicted disease:  Infiltration
# Actual output:    Pleural_Thickening
# -------------
# data/alien_test/00004858_058.png
# Model Output:  [{'Atelectasis': 1.273407e-29}, {'Cardiomegaly': 2.065282e-35}, {'Emphysema': 1.6244507e-35}, {'Hernia': 6.277695e-28}, {'Mass': 1.0}]
# [(1.0, 'Mass'), (6.277695e-28, 'Hernia'), (1.273407e-29, 'Atelectasis'), (2.065282e-35, 'Cardiomegaly'), (1.6244507e-35, 'Emphysema')]
# Most Probable Predicted disease:  Mass
# Actual output:    Atelectasis|Pleural_Thickening
# -------------
# data/alien_test/00004904_013.png
# Model Output:  [{'Edema': 2.829978e-13}, {'Infiltration': 1.0}]
# [(1.0, 'Infiltration'), (2.829978e-13, 'Edema')]
# Most Probable Predicted disease:  Infiltration
# Actual output:    Consolidation|Effusion|Mass
# -------------
# data/alien_test/00004911_033.png
# Model Output:  [{'Edema': 2.0139099e-28}, {'Emphysema': 5.0908366e-21}, {'Hernia': 4.5836764e-33}, {'Infiltration': 1.0}, {'Mass': 6.651433e-38}]
# [(1.0, 'Infiltration'), (5.0908366e-21, 'Emphysema'), (2.0139099e-28, 'Edema'), (4.5836764e-33, 'Hernia'), (6.651433e-38, 'Mass')]
# Most Probable Predicted disease:  Infiltration
# Actual output:    Effusion
# -------------
# data/alien_test/00005026_015.png
# Model Output:  [{'Emphysema': 1.9972719e-22}, {'Hernia': 9.2708026e-29}, {'Infiltration': 0.9759913}, {'Mass': 0.024008729}]
# [(0.9759913, 'Infiltration'), (0.024008729, 'Mass'), (1.9972719e-22, 'Emphysema'), (9.2708026e-29, 'Hernia')]
# Most Probable Predicted disease:  Infiltration
# Actual output:    Effusion
# -------------
# data/alien_test/00005064_000.png
# Model Output:  [{'Cardiomegaly': 1.0}, {'Emphysema': 6.2708095e-18}, {'Infiltration': 7.31712e-27}]
# [(1.0, 'Cardiomegaly'), (6.2708095e-18, 'Emphysema'), (7.31712e-27, 'Infiltration')]
# Most Probable Predicted disease:  Cardiomegaly
# Actual output:    Atelectasis|Cardiomegaly|Effusion
# -------------
# data/alien_test/00005089_048.png
# Model Output:  [{'Atelectasis': 2.3319779e-32}, {'Cardiomegaly': 2.4245434e-37}, {'Hernia': 2.2354182e-22}, {'Infiltration': 1.2270354e-23}, {'Mass': 1.0}]
# [(1.0, 'Mass'), (2.2354182e-22, 'Hernia'), (1.2270354e-23, 'Infiltration'), (2.3319779e-32, 'Atelectasis'), (2.4245434e-37, 'Cardiomegaly')]
# Most Probable Predicted disease:  Mass
# Actual output:    Cardiomegaly|Effusion|Fibrosis
# -------------
# data/alien_test/00005138_012.png
# Model Output:  [{'Cardiomegaly': 1.0}]
# [(1.0, 'Cardiomegaly')]
# Most Probable Predicted disease:  Cardiomegaly
# Actual output:    Nodule|Pleural_Thickening
# -------------
# data/alien_test/00005200_001.png
# Model Output:  [{'Cardiomegaly': 9.9686615e-37}, {'Edema': 9.039306e-18}, {'Emphysema': 5.0791554e-30}, {'Infiltration': 1.0}, {'Mass': 5.573345e-21}, {'No Finding': 1.17579656e-29}]
# [(1.0, 'Infiltration'), (9.039306e-18, 'Edema'), (5.573345e-21, 'Mass'), (1.17579656e-29, 'No Finding'), (5.0791554e-30, 'Emphysema')]
# Most Probable Predicted disease:  Infiltration
# Actual output:    Effusion
# -------------
# data/alien_test/00005298_005.png
# Model Output:  [{'Edema': 1.3695272e-13}, {'Emphysema': 1.0}, {'No Finding': 2.9930642e-16}]
# [(1.0, 'Emphysema'), (1.3695272e-13, 'Edema'), (2.9930642e-16, 'No Finding')]
# Most Probable Predicted disease:  Emphysema
# Actual output:    Infiltration|Pleural_Thickening
# -------------
# data/alien_test/00005876_000.png
# Model Output:  [{'Infiltration': 1.0}]
# [(1.0, 'Infiltration')]
# Most Probable Predicted disease:  Infiltration
# Actual output:    Infiltration|Pleural_Thickening
# -------------
# data/alien_test/00006304_011.png
# Model Output:  [{'Cardiomegaly': 1.0914895e-07}, {'Consolidation': 0.056215893}, {'Edema': 0.943784}, {'Emphysema': 5.3343007e-11}, {'Fibrosis': 5.110285e-31}, {'Infiltration': 1.6120076e-17}, {'No Finding': 1.0112731e-13}, {'Nodule': 1.9293921e-34}]
# [(0.943784, 'Edema'), (0.056215893, 'Consolidation'), (1.0914895e-07, 'Cardiomegaly'), (5.3343007e-11, 'Emphysema'), (1.0112731e-13, 'No Finding')]
# Most Probable Predicted disease:  Edema
# Actual output:    Infiltration|Nodule|Pleural_Thickening
# -------------
# data/alien_test/00006434_003.png
# Model Output:  [{'Infiltration': 1.0}]
# [(1.0, 'Infiltration')]
# Most Probable Predicted disease:  Infiltration
# Actual output:    Infiltration|Nodule
# -------------
# data/alien_test/00006481_024.png
# Model Output:  [{'Atelectasis': 7.99783e-34}, {'Cardiomegaly': 8.920851e-29}, {'Emphysema': 1.11310685e-26}, {'Fibrosis': 3.3522935e-33}, {'Hernia': 4.1358968e-27}, {'Infiltration': 0.99998677}, {'Mass': 1.3286254e-05}, {'No Finding': 1.3487158e-33}]
# [(0.99998677, 'Infiltration'), (1.3286254e-05, 'Mass'), (1.11310685e-26, 'Emphysema'), (4.1358968e-27, 'Hernia'), (8.920851e-29, 'Cardiomegaly')]
# Most Probable Predicted disease:  Infiltration
# Actual output:    Effusion|Infiltration|Pleural_Thickening
# -------------
# data/alien_test/00006642_014.png
# Model Output:  [{'Infiltration': 1.0}]
# [(1.0, 'Infiltration')]
# Most Probable Predicted disease:  Infiltration
# Actual output:    Infiltration|Nodule
# -------------
# data/alien_test/00006821_005.png
# Model Output:  [{'Edema': 1.16374486e-35}, {'Emphysema': 1.2821765e-28}, {'Infiltration': 1.0}, {'Mass': 1.546645e-16}]
# [(1.0, 'Infiltration'), (1.546645e-16, 'Mass'), (1.2821765e-28, 'Emphysema'), (1.16374486e-35, 'Edema')]
# Most Probable Predicted disease:  Infiltration
# Actual output:    Atelectasis|Nodule
# -------------
# data/alien_test/00006925_004.png
# Model Output:  [{'Emphysema': 1.7826406e-35}, {'Infiltration': 1.0}, {'Mass': 1.1519373e-15}]
# [(1.0, 'Infiltration'), (1.1519373e-15, 'Mass'), (1.7826406e-35, 'Emphysema')]
# Most Probable Predicted disease:  Infiltration
# Actual output:    Nodule
# -------------
# data/alien_test/00006953_003.png
# Model Output:  [{'Infiltration': 1.0}]
# [(1.0, 'Infiltration')]
# Most Probable Predicted disease:  Infiltration
# Actual output:    Atelectasis|Effusion|Pneumothorax
# -------------
# data/alien_test/00007808_001.png
# Model Output:  [{'Infiltration': 1.0}]
# [(1.0, 'Infiltration')]
# Most Probable Predicted disease:  Infiltration
# Actual output:    Effusion|Mass|Nodule
# -------------
# data/alien_test/00007816_006.png
# Model Output:  [{'Hernia': 9.7765317e-20}, {'Infiltration': 1.0}, {'Mass': 3.6700573e-11}]
# [(1.0, 'Infiltration'), (3.6700573e-11, 'Mass'), (9.7765317e-20, 'Hernia')]
# Most Probable Predicted disease:  Infiltration
# Actual output:    Infiltration
# -------------
# data/alien_test/00007816_007.png
# Model Output:  [{'Edema': 3.075156e-38}, {'Infiltration': 1.0}]
# [(1.0, 'Infiltration'), (3.075156e-38, 'Edema')]
# Most Probable Predicted disease:  Infiltration
# Actual output:    Infiltration
# -------------
# data/alien_test/00008008_059.png
# Model Output:  [{'Hernia': 1.4975286e-30}, {'Infiltration': 1.0}, {'Mass': 2.4967439e-19}]
# [(1.0, 'Infiltration'), (2.4967439e-19, 'Mass'), (1.4975286e-30, 'Hernia')]
# Most Probable Predicted disease:  Infiltration
# Actual output:    Nodule
# -------------
# data/alien_test/00008008_065.png
# Model Output:  [{'Hernia': 6.4369457e-35}, {'Infiltration': 1.0}]
# [(1.0, 'Infiltration'), (6.4369457e-35, 'Hernia')]
# Most Probable Predicted disease:  Infiltration
# Actual output:    Mass|Nodule|Pleural_Thickening
# -------------
# data/alien_test/00008008_068.png
# Model Output:  [{'Emphysema': 5.684828e-37}, {'Hernia': 1.2905644e-18}, {'Infiltration': 1.0}, {'Mass': 5.479319e-23}]
# [(1.0, 'Infiltration'), (1.2905644e-18, 'Hernia'), (5.479319e-23, 'Mass'), (5.684828e-37, 'Emphysema')]
# Most Probable Predicted disease:  Infiltration
# Actual output:    Infiltration
# -------------
# data/alien_test/00008010_000.png
# Model Output:  [{'Infiltration': 1.0}, {'Mass': 5.499292e-32}]
# [(1.0, 'Infiltration'), (5.499292e-32, 'Mass')]
# Most Probable Predicted disease:  Infiltration
# Actual output:    Fibrosis|Hernia|Mass
# -------------
# data/alien_test/00008067_006.png
# Model Output:  [{'Consolidation': 3.9505503e-28}, {'Edema': 0.6155267}, {'Emphysema': 5.500702e-27}, {'Infiltration': 0.3844733}]
# [(0.6155267, 'Edema'), (0.3844733, 'Infiltration'), (5.500702e-27, 'Emphysema'), (3.9505503e-28, 'Consolidation')]
# Most Probable Predicted disease:  Edema
# Actual output:    Infiltration
# -------------
# data/alien_test/00008067_026.png
# Model Output:  [{'Edema': 1.7438172e-14}, {'Infiltration': 1.0}]
# [(1.0, 'Infiltration'), (1.7438172e-14, 'Edema')]
# Most Probable Predicted disease:  Infiltration
# Actual output:    Consolidation|Infiltration
# -------------
# data/alien_test/00008154_000.png
# Model Output:  [{'Cardiomegaly': 4.642457e-38}, {'Hernia': 2.5689689e-37}, {'Infiltration': 8.306425e-26}, {'Mass': 1.0}, {'No Finding': 2.8360804e-38}]
# [(1.0, 'Mass'), (8.306425e-26, 'Infiltration'), (2.5689689e-37, 'Hernia'), (4.642457e-38, 'Cardiomegaly'), (2.8360804e-38, 'No Finding')]
# Most Probable Predicted disease:  Mass
# Actual output:    Atelectasis|Consolidation|Mass|Pneumonia
# -------------
# data/alien_test/00008195_000.png
# Model Output:  [{'Infiltration': 1.0}, {'Mass': 4.5216433e-10}, {'No Finding': 4.398844e-31}]
# [(1.0, 'Infiltration'), (4.5216433e-10, 'Mass'), (4.398844e-31, 'No Finding')]
# Most Probable Predicted disease:  Infiltration
# Actual output:    Effusion|Pleural_Thickening
# -------------
# data/alien_test/00008291_000.png
# Model Output:  [{'Cardiomegaly': 2.3311977e-30}, {'Emphysema': 2.0528647e-19}, {'Infiltration': 8.491879e-23}, {'Mass': 1.0}, {'No Finding': 6.570783e-23}]
# [(1.0, 'Mass'), (2.0528647e-19, 'Emphysema'), (8.491879e-23, 'Infiltration'), (6.570783e-23, 'No Finding'), (2.3311977e-30, 'Cardiomegaly')]
# Most Probable Predicted disease:  Mass
# Actual output:    Infiltration
# -------------
# data/alien_test/00008304_007.png
# Model Output:  [{'Cardiomegaly': 1.0}]
# [(1.0, 'Cardiomegaly')]
# Most Probable Predicted disease:  Cardiomegaly
# Actual output:    Infiltration
# -------------
# data/alien_test/00008346_000.png
# Model Output:  [{'Atelectasis': 3.0022397e-28}, {'Cardiomegaly': 5.398302e-38}, {'Effusion': 6.606968e-33}, {'Emphysema': 5.4916264e-37}, {'Hernia': 1.2719534e-17}, {'Infiltration': 2.0620722e-33}, {'Mass': 1.0}, {'No Finding': 2.0981326e-36}]
# [(1.0, 'Mass'), (1.2719534e-17, 'Hernia'), (3.0022397e-28, 'Atelectasis'), (6.606968e-33, 'Effusion'), (2.0620722e-33, 'Infiltration')]
# Most Probable Predicted disease:  Mass
# Actual output:    Mass|Nodule
# -------------
# data/alien_test/00008626_024.png
# Model Output:  [{'Hernia': 6.036501e-38}, {'Infiltration': 1.0}, {'Mass': 7.2959765e-24}]
# [(1.0, 'Infiltration'), (7.2959765e-24, 'Mass'), (6.036501e-38, 'Hernia')]
# Most Probable Predicted disease:  Infiltration
# Actual output:    Nodule
# -------------
# data/alien_test/00008636_003.png
# Model Output:  [{'Emphysema': 4.7501304e-34}, {'Infiltration': 1.0}, {'Mass': 6.9518024e-34}]
# [(1.0, 'Infiltration'), (6.9518024e-34, 'Mass'), (4.7501304e-34, 'Emphysema')]
# Most Probable Predicted disease:  Infiltration
# Actual output:    Nodule
# -------------
# data/alien_test/00008701_004.png
# Model Output:  [{'Cardiomegaly': 4.9929435e-28}, {'Consolidation': 1.346065e-27}, {'Edema': 5.4512e-10}, {'Emphysema': 8.226587e-17}, {'Fibrosis': 1.8534753e-36}, {'Infiltration': 1.0}, {'Mass': 2.8993513e-12}, {'No Finding': 3.0550333e-23}]
# [(1.0, 'Infiltration'), (5.4512e-10, 'Edema'), (2.8993513e-12, 'Mass'), (8.226587e-17, 'Emphysema'), (3.0550333e-23, 'No Finding')]
# Most Probable Predicted disease:  Infiltration
# Actual output:    Effusion|Infiltration|Nodule
# -------------
# data/alien_test/00008841_028.png
# Model Output:  [{'Atelectasis': 2.5265496e-30}, {'Cardiomegaly': 3.4110205e-20}, {'Consolidation': 0.00012437956}, {'Edema': 0.99987555}, {'Effusion': 1.3857711e-31}, {'Emphysema': 6.039056e-19}, {'Infiltration': 1.9623752e-19}, {'Mass': 2.898707e-28}, {'No Finding': 4.527774e-19}]
# [(0.99987555, 'Edema'), (0.00012437956, 'Consolidation'), (6.039056e-19, 'Emphysema'), (4.527774e-19, 'No Finding'), (1.9623752e-19, 'Infiltration')]
# Most Probable Predicted disease:  Edema
# Actual output:    Atelectasis|Emphysema
# -------------
# data/alien_test/00009349_014.png
# Model Output:  [{'Infiltration': 1.0}]
# [(1.0, 'Infiltration')]
# Most Probable Predicted disease:  Infiltration
# Actual output:    Atelectasis|Emphysema|Infiltration|Mass|Pneumo...
# -------------
# data/alien_test/00009368_008.png
# Model Output:  [{'Edema': 0.9981376}, {'Emphysema': 0.0018623607}, {'Infiltration': 4.8767e-25}]
# [(0.9981376, 'Edema'), (0.0018623607, 'Emphysema'), (4.8767e-25, 'Infiltration')]
# Most Probable Predicted disease:  Edema
# Actual output:    Atelectasis|Hernia|Pneumothorax
# -------------
# data/alien_test/00009600_009.png
# Model Output:  [{'Edema': 1.1443069e-24}, {'Infiltration': 1.0}]
# [(1.0, 'Infiltration'), (1.1443069e-24, 'Edema')]
# Most Probable Predicted disease:  Infiltration
# Actual output:    Cardiomegaly|Effusion|Infiltration
# -------------
# data/alien_test/00009863_007.png
# Model Output:  [{'Edema': 1.996467e-31}, {'Infiltration': 1.0}]
# [(1.0, 'Infiltration'), (1.996467e-31, 'Edema')]
# Most Probable Predicted disease:  Infiltration
# Actual output:    Atelectasis|Consolidation|Edema|Infiltration|P...
# -------------
# data/alien_test/00010007_087.png
# Model Output:  [{'Consolidation': 1.0}, {'Edema': 6.3067956e-10}]
# [(1.0, 'Consolidation'), (6.3067956e-10, 'Edema')]
# Most Probable Predicted disease:  Consolidation
# Actual output:    Cardiomegaly|Effusion|Infiltration
# -------------
# data/alien_test/00011104_004.png
# Model Output:  [{'Atelectasis': 6.272976e-28}, {'Emphysema': 1.1322232e-30}, {'Hernia': 6.1467416e-21}, {'Infiltration': 5.3349015e-07}, {'Mass': 0.9999995}, {'Nodule': 2.801681e-30}]
# [(0.9999995, 'Mass'), (5.3349015e-07, 'Infiltration'), (6.1467416e-21, 'Hernia'), (6.272976e-28, 'Atelectasis'), (2.801681e-30, 'Nodule')]
# Most Probable Predicted disease:  Mass
# Actual output:    Infiltration|Nodule|Pneumonia
# -------------
# data/alien_test/00011136_020.png
# Model Output:  [{'Cardiomegaly': 5.785266e-29}, {'Consolidation': 3.9512263e-25}, {'Edema': 2.811212e-10}, {'Emphysema': 1.6506562e-19}, {'Fibrosis': 1.157738e-32}, {'Infiltration': 1.0}, {'Mass': 1.8868362e-18}, {'No Finding': 8.512217e-30}]
# [(1.0, 'Infiltration'), (2.811212e-10, 'Edema'), (1.8868362e-18, 'Mass'), (1.6506562e-19, 'Emphysema'), (3.9512263e-25, 'Consolidation')]
# Most Probable Predicted disease:  Infiltration
# Actual output:    Atelectasis|Cardiomegaly|Effusion
# -------------
# data/alien_test/00011379_039.png
# Model Output:  [{'Cardiomegaly': 1.0}, {'No Finding': 4.9739952e-11}]
# [(1.0, 'Cardiomegaly'), (4.9739952e-11, 'No Finding')]
# Most Probable Predicted disease:  Cardiomegaly
# Actual output:    Pneumothorax
# -------------
# data/alien_test/00011470_009.png
# Model Output:  [{'Atelectasis': 9.017791e-38}, {'Emphysema': 3.741809e-29}, {'Hernia': 1.3314813e-32}, {'Infiltration': 1.0}, {'Mass': 4.7779528e-12}]
# [(1.0, 'Infiltration'), (4.7779528e-12, 'Mass'), (3.741809e-29, 'Emphysema'), (1.3314813e-32, 'Hernia'), (9.017791e-38, 'Atelectasis')]
# Most Probable Predicted disease:  Infiltration
# Actual output:    Edema|Effusion
# -------------
# data/alien_test/00011553_015.png
# Model Output:  [{'Cardiomegaly': 0.00041486602}, {'No Finding': 8.450974e-23}, {'Nodule': 0.9995851}]
# [(0.9995851, 'Nodule'), (0.00041486602, 'Cardiomegaly'), (8.450974e-23, 'No Finding')]
# Most Probable Predicted disease:  Nodule
# Actual output:    Cardiomegaly
# -------------
# data/alien_test/00013209_013.png
# Model Output:  [{'Atelectasis': 3.9419644e-19}, {'Cardiomegaly': 2.8028887e-31}, {'Effusion': 3.7932213e-19}, {'Emphysema': 7.208454e-29}, {'Hernia': 4.281005e-18}, {'Infiltration': 1.1212475e-28}, {'Mass': 1.0}, {'Nodule': 5.3838174e-33}]
# [(1.0, 'Mass'), (4.281005e-18, 'Hernia'), (3.9419644e-19, 'Atelectasis'), (3.7932213e-19, 'Effusion'), (1.1212475e-28, 'Infiltration')]
# Most Probable Predicted disease:  Mass
# Actual output:    Pneumothorax
# -------------
# data/alien_test/00013890_013.png
# Model Output:  [{'Atelectasis': 3.5302374e-23}, {'Cardiomegaly': 4.0815186e-07}, {'Effusion': 0.20087461}, {'Emphysema': 4.1229218e-16}, {'Fibrosis': 1.9081377e-29}, {'Hernia': 3.240878e-29}, {'Mass': 0.799125}, {'No Finding': 3.4333572e-20}, {'Nodule': 2.2702361e-28}]
# [(0.799125, 'Mass'), (0.20087461, 'Effusion'), (4.0815186e-07, 'Cardiomegaly'), (4.1229218e-16, 'Emphysema'), (3.4333572e-20, 'No Finding')]
# Most Probable Predicted disease:  Mass
# Actual output:    Cardiomegaly|Effusion|Infiltration
# -------------
# data/alien_test/00013993_100.png
# Model Output:  [{'Cardiomegaly': 6.085934e-16}, {'Consolidation': 1.0}, {'Edema': 5.9974922e-27}, {'No Finding': 2.7546382e-31}]
# [(1.0, 'Consolidation'), (6.085934e-16, 'Cardiomegaly'), (5.9974922e-27, 'Edema'), (2.7546382e-31, 'No Finding')]
# Most Probable Predicted disease:  Consolidation
# Actual output:    Atelectasis|Consolidation|Effusion|Infiltratio...
# -------------
# data/alien_test/00014223_009.png
# Model Output:  [{'Cardiomegaly': 3.8842682e-28}, {'Consolidation': 1.1006548e-15}, {'Edema': 1.0}, {'Effusion': 7.023522e-37}, {'Emphysema': 4.177626e-33}, {'Mass': 1.3918355e-38}]
# [(1.0, 'Edema'), (1.1006548e-15, 'Consolidation'), (3.8842682e-28, 'Cardiomegaly'), (4.177626e-33, 'Emphysema'), (7.023522e-37, 'Effusion')]
# Most Probable Predicted disease:  Edema
# Actual output:    Cardiomegaly|Edema|Mass
# -------------
# data/alien_test/00015956_010.png
# Model Output:  [{'Edema': 3.2622638e-25}, {'Infiltration': 1.0}]
# [(1.0, 'Infiltration'), (3.2622638e-25, 'Edema')]
# Most Probable Predicted disease:  Infiltration
# Actual output:    Cardiomegaly|Effusion|Nodule
# -------------
# data/alien_test/00017417_000.png
# Model Output:  [{'Emphysema': 2.1635054e-35}, {'Hernia': 8.3324506e-33}, {'Infiltration': 1.3155066e-18}, {'Mass': 1.0}]
# [(1.0, 'Mass'), (1.3155066e-18, 'Infiltration'), (8.3324506e-33, 'Hernia'), (2.1635054e-35, 'Emphysema')]
# Most Probable Predicted disease:  Mass
# Actual output:    Cardiomegaly
# -------------
#
#
#
# Number of correctly detected images:  50 / 100
# Number of wrongly detected images:  50 / 100
# Execution Time: 22.986330032348633 seconds
